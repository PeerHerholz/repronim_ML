# %%
which python
# Out:
# /Users/peerherholz/anaconda3/envs/repronim_ml/bin/python

# %%
conda env export --no-builds > environment.yml

# %%
docker images
# Out:
# REPOSITORY             TAG       IMAGE ID       CREATED              SIZE
# repronim_ml            latest    35867f73b6df   About a minute ago   3.51GB
# kaczmarj/neurodocker   0.7.0     9a76e0dbb85b   5 years ago          82.6MB
# kaczmarj/neurodocker   0.6.0     7029883696dd   5 years ago          79.3MB

# %%
docker tag repronim_ml peerherholz/repronim_ml:0.2

# %%
docker images
# Out:
# REPOSITORY                TAG       IMAGE ID       CREATED         SIZE
# repronim_ml               latest    35867f73b6df   2 minutes ago   3.51GB
# peerherholz/repronim_ml   0.2       35867f73b6df   2 minutes ago   3.51GB
# kaczmarj/neurodocker      0.7.0     9a76e0dbb85b   5 years ago     82.6MB
# kaczmarj/neurodocker      0.6.0     7029883696dd   5 years ago     79.3MB

# %%
docker push peerherholz/repronim_ml:0.2
# Out:
# The push refers to repository [docker.io/peerherholz/repronim_ml]
#
# ef12a510: Preparing
# d0bfe802: Preparing
# e8d17b82: Preparing
# 769c3f8c: Preparing
# 2413f64f: Preparing
# context canceledg  785.4MB/3.351GBntu

# %%
docker images
# Out:
# REPOSITORY                TAG       IMAGE ID       CREATED       SIZE
# repronim_ml               latest    35867f73b6df   2 hours ago   3.51GB
# peerherholz/repronim_ml   0.2       35867f73b6df   2 hours ago   3.51GB
# kaczmarj/neurodocker      0.7.0     9a76e0dbb85b   5 years ago   82.6MB
# kaczmarj/neurodocker      0.6.0     7029883696dd   5 years ago   79.3MB

# %%
docker rmi -f 9a76e0dbb85b
# Out:
# Untagged: kaczmarj/neurodocker:0.7.0
# Untagged: kaczmarj/neurodocker@sha256:3a99c0356dffc386f796ba2f4829d5697c14837d461ad900dc426b0746684ef0
# Deleted: sha256:9a76e0dbb85b9d182544603359272943a5eb681c903aee72acf1e19570dd31c8
# Deleted: sha256:899ee3452c0f268560f08dc2548c2e3e30c9ddfe0fe1cc74d303bfe0235cdb4f
# Deleted: sha256:2d40243c286af688470e19d60331906ce81d7e221539dff0e3720992a39b2473
# Deleted: sha256:178255adf43f5bab85e0a58ce6bc9e17dc66e7419e4b554727d69ae0d8bebb72

# %%
cp -r . ~/Desktop/repronim_ml_bk

# %%
sudo rm -rf repronim_ml_showcase
# Out:
# Password:
# sudo: a password is required
